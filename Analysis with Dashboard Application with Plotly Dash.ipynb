# %% [markdown]
# # Dashboard application

# %% [markdown]
# #For this Application are required the next tasks:

# %% [markdown]
# ![Tasks.gif](attachment:Tasks.gif)

# %% [markdown]
# ![Instructions1.gif](attachment:Instructions1.gif)

# %% [markdown]
# ![port%208050.gif](attachment:port%208050.gif)

# %% [markdown]
# # RESULTS

# %% [markdown]
# Total Success Launch by Site and Correlation between PayloadMass and Sucess colored by Booster Version

# %% [markdown]
# ![Site1Pie.gif](attachment:Site1Pie.gif)

# %% [markdown]
# ![Site1Scatter.gif](attachment:Site1Scatter.gif)

# %% [markdown]
# RESULTS FOR SOME SITES

# %% [markdown]
# ![Site1Pie.gif](attachment:Site1Pie.gif)

# %% [markdown]
# ![Site1Scatter.gif](attachment:Site1Scatter.gif)

# %% [markdown]
# ![Site2Pie.gif](attachment:Site2Pie.gif)

# %% [markdown]
# ![Site2Scatter.gif](attachment:Site2Scatter.gif)

# %% [markdown]
# ![Site3Pie.gif](attachment:Site3Pie.gif)

# %% [markdown]
# ![Site3Scatter_range.gif](attachment:Site3Scatter_range.gif)

# %% [markdown]
# IMAGES OF THE CODE

# %% [markdown]
# ![DROPDOWN.gif](attachment:DROPDOWN.gif)

# %% [markdown]
# ![RANGE_PIE.gif](attachment:RANGE_PIE.gif)

# %% [markdown]
# ![CALLBACK_SCATTER.gif](attachment:CALLBACK_SCATTER.gif)
